# %% [markdown]
# # Introduction

# %% [markdown]
# In this project, we are going to apply the K-Means clustering to solve for the following problems:
#
# - How has the price of rice changed in different regions over time?
# - Which regions experience the most volatile rice prices?
# - Is there an existing seasonal pattern in rice price volatility?

# %%
import pandas as pd

pd.set_option('display.max_columns', 500)
food_prices_data = pd.read_csv("wfp_food_prices_phl.csv", skiprows=[1])

# %% [markdown]
# # Data Cleaning and Exploration

# %%
# Number of data and features 
print(food_prices_data.shape)
print(len(str(food_prices_data.shape))*'-')

# Check how many types of data are in the dataset
print(food_prices_data.dtypes.value_counts())
print(len(str(food_prices_data.shape))*'-')

# Check the first 16 columns
food_prices_data.head(16)
# Out:
# (121512, 14)
# ------------
# object     10
# float64     4
# Name: count, dtype: int64
# ------------
#           date                   admin1               admin2          market  \
# 0   2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 1   2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 2   2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 3   2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 4   2000-01-15               Region III          Nueva Ecija         Palayan
# 5   2000-01-15               Region III          Nueva Ecija         Palayan
# 6   2000-01-15               Region III          Nueva Ecija         Palayan
# 7   2000-01-15                Region IX    Zamboanga del Sur  Zamboanga City
# 8   2000-01-15                Region VI               Iloilo     Iloilo City
# 9   2000-01-15                Region VI               Iloilo     Iloilo City
# 10  2000-01-15                Region VI               Iloilo     Iloilo City
# 11  2000-01-15                Region VI               Iloilo     Iloilo City
# 12  2000-01-15               Region VII                 Cebu       Cebu City
# 13  2000-01-15               Region VII                 Cebu       Cebu City
# 14  2000-01-15               Region VII                 Cebu       Cebu City
# 15  2000-01-15               Region VII                 Cebu       Cebu City
#
#      latitude   longitude            category                commodity unit  \
# 0   14.604167  120.982222  cereals and tubers     Maize flour (yellow)   KG
# 1   14.604167  120.982222  cereals and tubers  Rice (milled, superior)   KG
# 2   14.604167  120.982222  cereals and tubers  Rice (milled, superior)   KG
# 3   14.604167  120.982222  cereals and tubers   Rice (regular, milled)   KG
# 4   15.541500  121.084800  cereals and tubers  Rice (milled, superior)   KG
# 5   15.541500  121.084800  cereals and tubers  Rice (milled, superior)   KG
# 6   15.541500  121.084800  cereals and tubers   Rice (regular, milled)   KG
# 7    6.910255  122.071715  cereals and tubers   Rice (regular, milled)   KG
# 8   10.696944  122.564444  cereals and tubers  Rice (milled, superior)   KG
# 9   10.696944  122.564444  cereals and tubers  Rice (milled, superior)   KG
# 10  10.696944  122.564444  cereals and tubers   Rice (regular, milled)   KG
# 11  10.696944  122.564444  cereals and tubers   Rice (regular, milled)   KG
# 12  10.311111  123.891667  cereals and tubers      Maize flour (white)   KG
# 13  10.311111  123.891667  cereals and tubers  Rice (milled, superior)   KG
# 14  10.311111  123.891667  cereals and tubers  Rice (milled, superior)   KG
# 15  10.311111  123.891667  cereals and tubers   Rice (regular, milled)   KG
#
#    priceflag  pricetype currency  price  usdprice
# 0     actual     Retail      PHP  15.00    0.3717
# 1     actual     Retail      PHP  20.00    0.4957
# 2     actual  Wholesale      PHP  18.35    0.4548
# 3     actual  Wholesale      PHP  16.35    0.4052
# 4     actual     Retail      PHP  19.00    0.4709
# 5     actual  Wholesale      PHP  18.00    0.4461
# 6     actual     Retail      PHP  18.10    0.4486
# 7     actual     Retail      PHP  16.90    0.4188
# 8     actual     Retail      PHP  20.40    0.5056
# 9     actual  Wholesale      PHP  15.60    0.3866
# 10    actual     Retail      PHP  17.80    0.4411
# 11    actual  Wholesale      PHP  14.70    0.3643
# 12    actual     Retail      PHP  14.90    0.3693
# 13    actual     Retail      PHP  19.60    0.4857
# 14    actual  Wholesale      PHP  18.70    0.4634
# 15    actual     Retail      PHP  18.10    0.4486

# %% [markdown]
# ### Check for Missing Values

# %%
food_prices_data.isnull().sum()
# Out:
# date         0
# admin1       0
# admin2       0
# market       0
# latitude     0
# longitude    0
# category     0
# commodity    0
# unit         0
# priceflag    0
# pricetype    0
# currency     0
# price        0
# usdprice     0
# dtype: int64

# %% [markdown]
# ### Remove Unnecessary Data

# %%
food_prices_data = food_prices_data.drop(columns=["category", "currency"])

food_prices_data.head()
# Out:
#          date                   admin1               admin2        market  \
# 0  2000-01-15  National Capital region  Metropolitan Manila  Metro Manila
# 1  2000-01-15  National Capital region  Metropolitan Manila  Metro Manila
# 2  2000-01-15  National Capital region  Metropolitan Manila  Metro Manila
# 3  2000-01-15  National Capital region  Metropolitan Manila  Metro Manila
# 4  2000-01-15               Region III          Nueva Ecija       Palayan
#
#     latitude   longitude                commodity unit priceflag  pricetype  \
# 0  14.604167  120.982222     Maize flour (yellow)   KG    actual     Retail
# 1  14.604167  120.982222  Rice (milled, superior)   KG    actual     Retail
# 2  14.604167  120.982222  Rice (milled, superior)   KG    actual  Wholesale
# 3  14.604167  120.982222   Rice (regular, milled)   KG    actual  Wholesale
# 4  15.541500  121.084800  Rice (milled, superior)   KG    actual     Retail
#
#    price  usdprice
# 0  15.00    0.3717
# 1  20.00    0.4957
# 2  18.35    0.4548
# 3  16.35    0.4052
# 4  19.00    0.4709

# %% [markdown]
# Since we will only be focusing on rice prices, the category column is unnecessary because we will only have 1 category. Currency will also be removed since all values in price column are in PH

# %%
food_prices_data = food_prices_data.rename(columns={"price": "price (PH)"})

# %% [markdown]
# ### Check Column Values

# %%
food_prices_data["admin1"].value_counts()
# Out:
# admin1
# Region III                              10697
# Region VI                                9110
# Region V                                 9002
# Region VIII                              8510
# Region XI                                8127
# Cordillera Administrative region         7688
# Region IV-A                              7253
# Region X                                 7226
# Region IV-B                              7118
# Region XIII                              6959
# Region XII                               6955
# Region VII                               6731
# Region II                                5887
# Region I                                 5860
# Region IX                                5837
# Autonomous region in Muslim Mindanao     5613
# National Capital region                  2939
# Name: count, dtype: int64

# %%
food_prices_data["admin2"].value_counts()
# Out:
# admin2
# Davao del Sur        4719
# Zamboanga del Sur    3416
# Cebu                 3381
# Iloilo               3136
# South Cotabato       3066
#                      ...
# Dinagat Islands       878
# Sulu                  843
# Tawi-Tawi             698
# Lanao del Sur         644
# Camarines Sur         158
# Name: count, Length: 79, dtype: int64

# %%
food_prices_data["market"].value_counts()
# Out:
# market
# Davao City             3272
# Metro Manila           2939
# Cebu City              2087
# Iloilo City            1946
# Zamboanga City         1880
#                        ...
# Butuan City             265
# Cagayan de Oro City     253
# Davao Occidental        196
# Naga City               158
# Calapan City            146
# Name: count, Length: 108, dtype: int64

# %%
food_prices_data["pricetype"].value_counts()
# Out:
# pricetype
# Retail       116481
# Wholesale      4367
# Farm Gate       664
# Name: count, dtype: int64

# %%
commodity_counts = food_prices_data["commodity"].value_counts().reset_index()
commodity_counts.columns = ["commodity", "count"]
print(commodity_counts.to_string(index=False))
# Out:
#                           commodity  count
#              Rice (regular, milled)   4969
#                             Cabbage   4459
#                           Eggplants   3528
#                  Rice (well milled)   3518
#                     Fish (milkfish)   3389
#                        Bitter melon   3375
#                    Fish (roundscad)   3272
#                      Rice (special)   3235
#                             Coconut   3186
#                        Beans (mung)   3171
#             Meat (pork, with bones)   3170
#                      Fish (tilapia)   3074
#                   Bananas (lakatan)   2876
#                            Squashes   2875
#             Rice (milled, superior)   2850
#                           Anchovies   2764
#                               Choko   2630
#                              Ginger   2523
#                            Tomatoes   2507
#                                Eggs   2473
#                  Bananas (latundan)   2468
#                   Mangoes (carabao)   2412
#                                Crab   2393
#                      Shrimp (tiger)   2376
#                           Calamansi   2357
#                      Beans (string)   2200
#                        Bottle gourd   2012
#                Beans (green, fresh)   2007
#                         Meat (pork)   1980
#                        Onions (red)   1973
#                        Fish (fresh)   1830
#                             Carrots   1823
#       Meat (beef, chops with bones)   1815
#                   Cabbage (chinese)   1742
#                      Sweet potatoes   1648
#               Meat (chicken, whole)   1612
#                    Potatoes (Irish)   1427
#                      Bananas (saba)   1420
#                              Garlic   1241
#                    Fish (slipmouth)   1212
# Fish (redbelly yellowtail fusilier)   1193
#              Fish (threadfin bream)   1039
#                         Meat (beef)   1027
#                          Pineapples    957
#                                Taro    919
#                       Water spinach    918
#                   Shrimp (endeavor)    916
#                 Sweet Potato leaves    897
#                Groundnuts (shelled)    821
#              Fish (mackerel, fresh)    809
#                              Papaya    788
#                      Onions (white)    788
#                         Eggs (duck)    781
#                 Fish (frigate tuna)    753
#                   Semolina (yellow)    720
#                   Meat (pork, hock)    711
#                           Mandarins    692
#                Maize flour (yellow)    687
#                    Semolina (white)    668
#                        Rice (paddy)    664
#                      Rice (premium)    598
#              Groundnuts (unshelled)    369
#                 Maize flour (white)    316
#                      Maize (yellow)    272
#                      Mangoes (piko)    263
#                       Maize (white)    253
#                      Garlic (large)    170
#                       Sugar (brown)    161
#                       Sugar (white)    160
#               Meat (pork, with fat)    156
#                       Oil (cooking)    102
#                      Garlic (small)     84
#                             Chicken     68

# %%
food_prices_data["priceflag"].value_counts()
# Out:
# priceflag
# actual       117396
# aggregate      4116
# Name: count, dtype: int64

# %% [markdown]
# ### Change Data Types

# %% [markdown]
# Convert price, latitude, and longitude to numbers, and date to datetime format. Invalid entries are safely turned into NaN or NaT using errors="coerce".

# %%
food_prices_data["price (PH)"] = pd.to_numeric(food_prices_data["price (PH)"], errors="coerce")
food_prices_data["latitude"] = pd.to_numeric(food_prices_data["latitude"], errors="coerce")
food_prices_data["longitude"] = pd.to_numeric(food_prices_data["longitude"], errors="coerce")
food_prices_data["date"] = pd.to_datetime(food_prices_data["date"], errors="coerce")

print(food_prices_data.dtypes.value_counts())
# Out:
# object            7
# float64           4
# datetime64[ns]    1
# Name: count, dtype: int64

# %% [markdown]
# ### Filter Rice From Commodities

# %%
all_rice_df = food_prices_data[food_prices_data["commodity"].str.startswith("Rice", na=False)]

all_rice_df["commodity"].value_counts()
# Out:
# commodity
# Rice (regular, milled)     4969
# Rice (well milled)         3518
# Rice (special)             3235
# Rice (milled, superior)    2850
# Rice (paddy)                664
# Rice (premium)              598
# Name: count, dtype: int64

# %% [markdown]
# Since we only need rice commodities, we need to filter out all data that aren't rice

# %%
all_rice_df.head(16)
# Out:
#          date                   admin1               admin2          market  \
# 1  2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 2  2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 3  2000-01-15  National Capital region  Metropolitan Manila    Metro Manila
# 4  2000-01-15               Region III          Nueva Ecija         Palayan
# 5  2000-01-15               Region III          Nueva Ecija         Palayan
# 6  2000-01-15               Region III          Nueva Ecija         Palayan
# 7  2000-01-15                Region IX    Zamboanga del Sur  Zamboanga City
# 8  2000-01-15                Region VI               Iloilo     Iloilo City
# 9  2000-01-15                Region VI               Iloilo     Iloilo City
# 10 2000-01-15                Region VI               Iloilo     Iloilo City
# 11 2000-01-15                Region VI               Iloilo     Iloilo City
# 13 2000-01-15               Region VII                 Cebu       Cebu City
# 14 2000-01-15               Region VII                 Cebu       Cebu City
# 15 2000-01-15               Region VII                 Cebu       Cebu City
# 16 2000-01-15               Region VII                 Cebu       Cebu City
# 20 2000-01-15                Region XI        Davao del Sur      Davao City
#
#      latitude   longitude                commodity unit priceflag  pricetype  \
# 1   14.604167  120.982222  Rice (milled, superior)   KG    actual     Retail
# 2   14.604167  120.982222  Rice (milled, superior)   KG    actual  Wholesale
# 3   14.604167  120.982222   Rice (regular, milled)   KG    actual  Wholesale
# 4   15.541500  121.084800  Rice (milled, superior)   KG    actual     Retail
# 5   15.541500  121.084800  Rice (milled, superior)   KG    actual  Wholesale
# 6   15.541500  121.084800   Rice (regular, milled)   KG    actual     Retail
# 7    6.910255  122.071715   Rice (regular, milled)   KG    actual     Retail
# 8   10.696944  122.564444  Rice (milled, superior)   KG    actual     Retail
# 9   10.696944  122.564444  Rice (milled, superior)   KG    actual  Wholesale
# 10  10.696944  122.564444   Rice (regular, milled)   KG    actual     Retail
# 11  10.696944  122.564444   Rice (regular, milled)   KG    actual  Wholesale
# 13  10.311111  123.891667  Rice (milled, superior)   KG    actual     Retail
# 14  10.311111  123.891667  Rice (milled, superior)   KG    actual  Wholesale
# 15  10.311111  123.891667   Rice (regular, milled)   KG    actual     Retail
# 16  10.311111  123.891667   Rice (regular, milled)   KG    actual  Wholesale
# 20   7.180000  125.440000  Rice (milled, superior)   KG    actual     Retail
#
#     price (PH)  usdprice
# 1        20.00    0.4957
# 2        18.35    0.4548
# 3        16.35    0.4052
# 4        19.00    0.4709
# 5        18.00    0.4461
# 6        18.10    0.4486
# 7        16.90    0.4188
# 8        20.40    0.5056
# 9        15.60    0.3866
# 10       17.80    0.4411
# 11       14.70    0.3643
# 13       19.60    0.4857
# 14       18.70    0.4634
# 15       18.10    0.4486
# 16       16.90    0.4188
# 20       18.90    0.4684
